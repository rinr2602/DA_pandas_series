# %% [markdown]
# <a href="https://colab.research.google.com/github/rinr2602/DA_pandas_series/blob/main/EX7_artistfile_bioJSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-20d7a228-e9e2-4076-84c7-d45e756f6200" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20d7a228-e9e2-4076-84c7-d45e756f6200">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open('artists.json') as file:
  json_dict = json.load(file)

artists = json_normalize(json_dict)
artists.head()
# Out:
# <ipython-input-10-b01cab167bf6>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   artists = json_normalize(json_dict)
#                  name        years                         genre nationality  \
# 0   Amedeo Modigliani  1884 - 1920                 Expressionism     Italian
# 1  Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
# 2        Diego Rivera  1886 - 1957       Social Realism,Muralism     Mexican
# 3        Claude Monet  1840 - 1926                 Impressionism      French
# 4       Rene Magritte  1898 - 1967      Surrealism,Impressionism     Belgian
#
#                                                  bio
# 0  [{'full name': 'Amedeo Clemente Modigliani', '...
# 1  [{'full name': 'Wassily Wassilyevich Kandinsky...
# 2  [{'full name': 'Diego María de la Concepción J...
# 3  [{'full name': 'Oscar-Claude Monet', 'pronunci...
# 4  [{'full name': 'René François Ghislain Magritt...

# %%
biography = json_normalize(json_dict,record_path='bio',meta=['name'])
biography
# Out:
# <ipython-input-13-d6fc99e62793>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   biography = json_normalize(json_dict,record_path='bio',meta=['name'])
#                                            full name  \
# 0                         Amedeo Clemente Modigliani
# 1                     Wassily Wassilyevich Kandinsky
# 2  Diego María de la Concepción Juan Nepomuceno E...
# 3                                 Oscar-Claude Monet
# 4                    René François Ghislain Magritte
#
#                                        pronunciation  \
# 0                             [ameˈdɛːo modiʎˈʎaːni]
# 1  Васи́лий Васи́льевич Канди́нский, tr. Vasíliy ...
# 2                                   [ˈdjeɣo riˈβeɾa]
# 3                                        [klod mɔnɛ]
# 4                        [ʁəne fʁɑ̃swa ɡilɛ̃ maɡʁit]
#
#                                            life span  \
# 0                     12 July 1884 – 24 January 1920
# ...
