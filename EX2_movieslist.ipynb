# %% [markdown]
# <a href="https://colab.research.google.com/github/rinr2602/DA_pandas_series/blob/main/EX2_movieslist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f7dd79bf-ea4a-482a-8c73-0e2408ada6f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7dd79bf-ea4a-482a-8c73-0e2408ada6f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
movies = pd.read_csv('movies.csv',
                     sep='|',
                     header=None,
                     )
movies.head()
# Out:
#       0                  1      2      3            4   \
# 0  Color      James Cameron  723.0  178.0  760505847.0
# 1  Color     Gore Verbinski  302.0  169.0  309404152.0
# 2  Color         Sam Mendes  602.0  148.0  200074175.0
# 3  Color  Christopher Nolan  813.0  164.0  448130642.0
# 4      ?        Doug Walker      ?      ?            ?
#
#                                                   5       6    7      8   \
# 0                                            Avatar   3054.0  USA  PG-13
# 1          Pirates of the Caribbean: At World's End   1238.0  USA  PG-13
# 2                                           Spectre    994.0   UK  PG-13
# 3                             The Dark Knight Rises   2701.0  USA  PG-13
# 4  Star Wars: Episode VII - The Force Awakens    ...       ?    ?      ?
#
#               9       10   11           12
# 0  237,000,000.0  2009.0  7.9       Action
# 1  300,000,000.0  2007.0  7.1       Action
# 2  245,000,000.0  2015.0  6.8       Action
# ...

# %%
column_names = ['color', 'director_name', 'num_critic_for_reviews', 'duration',
                'gross', 'movie_title', 'num_user_for_reviews',	'country',
                'cotent_rating', 'budget', 'title_year', 'imdb_score', 'genre']

# %%
movies = pd.read_csv('movies.csv',
                     sep='|',
                     header=None,
                     names=column_names)
movies.head()
# Out:
#    color      director_name num_critic_for_reviews duration        gross  \
# 0  Color      James Cameron                  723.0    178.0  760505847.0
# 1  Color     Gore Verbinski                  302.0    169.0  309404152.0
# 2  Color         Sam Mendes                  602.0    148.0  200074175.0
# 3  Color  Christopher Nolan                  813.0    164.0  448130642.0
# 4      ?        Doug Walker                      ?        ?            ?
#
#                                          movie_title num_user_for_reviews  \
# 0                                            Avatar                3054.0
# 1          Pirates of the Caribbean: At World's End                1238.0
# 2                                           Spectre                 994.0
# 3                             The Dark Knight Rises                2701.0
# 4  Star Wars: Episode VII - The Force Awakens    ...                    ?
#
#   country cotent_rating         budget title_year  imdb_score        genre
# ...

# %%
movies = pd.read_csv('movies.csv',
                     sep='|',
                     header=None,
                     names=column_names,
                     na_values=['?'])
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration        gross  \
# 0  Color      James Cameron                   723.0     178.0  760505847.0
# 1  Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2  Color         Sam Mendes                   602.0     148.0  200074175.0
# 3  Color  Christopher Nolan                   813.0     164.0  448130642.0
# 4    NaN        Doug Walker                     NaN       NaN          NaN
#
#                                          movie_title  num_user_for_reviews  \
# 0                                            Avatar                 3054.0
# 1          Pirates of the Caribbean: At World's End                 1238.0
# 2                                           Spectre                  994.0
# 3                             The Dark Knight Rises                 2701.0
# 4  Star Wars: Episode VII - The Force Awakens    ...                   NaN
#
# ...

# %%
movies = pd.read_csv('movies.csv',
                     sep='|',
                     header=None,
                     names=column_names,
                     na_values=['?'],
                     thousands=',',
                     index_col='movie_title')
movies.head()
# Out:
#                                                     color      director_name  \
# movie_title
# Avatar                                              Color      James Cameron
# Pirates of the Caribbean: At World's End            Color     Gore Verbinski
# Spectre                                             Color         Sam Mendes
# The Dark Knight Rises                               Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens     ...    NaN        Doug Walker
#
#                                                     num_critic_for_reviews  \
# movie_title
# Avatar                                                               723.0
# Pirates of the Caribbean: At World's End                             302.0
# Spectre                                                              602.0
# The Dark Knight Rises                                                813.0
# Star Wars: Episode VII - The Force Awakens     ...                     NaN
#
# ...
