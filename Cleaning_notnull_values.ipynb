# %% [markdown]
# <a href="https://colab.research.google.com/github/rinr2602/DA_pandas_series/blob/main/Cleaning_notnull_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'Sex': ['M', 'F', 'F', 'D', '?'],
    'Age': [29, 30, 24, 290, 25],
})
df
# Out:
#   Sex  Age
# 0   M   29
# 1   F   30
# 2   F   24
# 3   D  290
# 4   ?   25

# %% [markdown]
# The previous DataFrame doesn't have any "missing value", but clearly has invalid data. 290 doesn't seem like a valid age, and D and ? don't correspond with any known sex category. How can you clean these not-missing, but clearly invalid values then?

# %% [markdown]
# ##Finding Unique Values
#
# The first step to clean invalid values is to notice them, then identify them and finally handle them appropriately (remove them, replace them, etc). Usually, for a "categorical" type of field (like Sex, which only takes values of a discrete set ('M', 'F')), we start by analyzing the variety of values present. For that, we use the unique() method

# %%
df['Sex'].unique()
# Out:
# array(['M', 'F', 'D', '?'], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# F    2
# M    1
# D    1
# ?    1
# Name: Sex, dtype: int64

# %%
df['Sex'].replace('D','F')
# Out:
# 0    M
# 1    F
# 2    F
# 3    F
# 4    ?
# Name: Sex, dtype: object

# %% [markdown]
# It can accept a dictionary of values to replace. For example, they also told you that there might be a few 'N's, that should actually be 'M's

# %%
df['Sex'].replace({'D':'F','N':'M'})
# Out:
# 0    M
# 1    F
# 2    F
# 3    F
# 4    ?
# Name: Sex, dtype: object

# %% [markdown]
# If there are many columns to replace, we can apply it at a "DataFrame" level

# %%
df.replace({
    'Sex':{'D':'F', 'N':'M'},
    'Age':{290:29}
})
# Out:
#   Sex  Age
# 0   M   29
# 1   F   30
# 2   F   24
# 3   F   29
# 4   ?   25

# %% [markdown]
# Here, 290 is replaceed with 29. Now what if, we want to remove all the extra zeros like this. For eg: 150 > 15 or 490 > 49.
#
# First, set a limit. Like anything above 100 is not possible.

# %%
df['Age']>100 #gives boolean list
df[df['Age']>100] #gives only the ages above 100
# Out:
#   Sex  Age
# 3   D  290

# %%
df.loc[df['Age']>100,'Age'] = df.loc[df['Age']>100,'Age']/10
# replace all the ages above 100 in the 'Age' column with the same value/10

# %%
df
# Out:
#   Sex  Age
# 0   M   29
# 1   F   30
# 2   F   24
# 3   D   29
# 4   ?   25

# %% [markdown]
# ## Duplicates
# Checking duplicate values is extremely simple. It'll behave differently between Series and DataFrames. Let's start with Series. As an example, let's say we're throwing a fancy party and we're inviting Ambassadors from Europe. But can only invite one ambassador per country. This is our original list, and as you can see, both the UK and Germany have duplicated ambassadors:

# %%
ambassadors = pd.Series([
    'France',
    'United Kingdom',
    'United Kingdom',
    'Italy',
    'Germany',
    'Germany',
    'Germany',
], index=[
    'Gérard Araud',
    'Kim Darroch',
    'Peter Westmacott',
    'Armando Varricchio',
    'Peter Wittig',
    'Peter Ammon',
    'Klaus Scharioth '
])
ambassadors
# Out:
# Gérard Araud                  France
# Kim Darroch           United Kingdom
# Peter Westmacott      United Kingdom
# Armando Varricchio             Italy
# Peter Wittig                 Germany
# Peter Ammon                  Germany
# Klaus Scharioth              Germany
# dtype: object

# %% [markdown]
# The two most important methods to deal with duplicates are duplicated (that will tell you which values are duplicates) and drop_duplicates (which will just get rid of duplicates)

# %%
ambassadors.duplicated() #gives boolean list
# Out:
# Gérard Araud          False
# Kim Darroch           False
# Peter Westmacott       True
# Armando Varricchio    False
# Peter Wittig          False
# Peter Ammon            True
# Klaus Scharioth        True
# dtype: bool

# %% [markdown]
# In this case duplicated didn't consider 'Kim Darroch', the first instance of the United Kingdom or 'Peter Wittig' as duplicates. That's because, by default, it'll consider the first occurrence of the value as not-duplicate. You can change this behavior with the keep parameter

# %%
ambassadors.duplicated(keep='last')
# Out:
# Gérard Araud          False
# Kim Darroch            True
# Peter Westmacott      False
# Armando Varricchio    False
# Peter Wittig           True
# Peter Ammon            True
# Klaus Scharioth       False
# dtype: bool

# %% [markdown]
# In this case, the result is "flipped", 'Kim Darroch' and 'Peter Wittig' (the first ambassadors of their countries) are considered duplicates, but 'Peter Westmacott' and 'Klaus Scharioth' are not duplicates. You can also choose to mark all of them as duplicates with keep=False

# %%
ambassadors.duplicated(keep=False)
# Out:
# Gérard Araud          False
# Kim Darroch            True
# Peter Westmacott       True
# Armando Varricchio    False
# Peter Wittig           True
# Peter Ammon            True
# Klaus Scharioth        True
# dtype: bool

# %% [markdown]
# A similar method is drop_duplicates, which just excludes the duplicated values and also accepts the keep parameter:

# %%
ambassadors.drop_duplicates()
# Out:
# Gérard Araud                  France
# Kim Darroch           United Kingdom
# Armando Varricchio             Italy
# Peter Wittig                 Germany
# dtype: object

# %%
ambassadors.drop_duplicates(keep='last')
# Out:
# Gérard Araud                  France
# Peter Westmacott      United Kingdom
# Armando Varricchio             Italy
# Klaus Scharioth              Germany
# dtype: object

# %%
ambassadors.drop_duplicates(keep=False)
# Out:
# Gérard Araud          France
# Armando Varricchio     Italy
# dtype: object

# %% [markdown]
# ###Duplicates in DataFrames
#
# Conceptually speaking, duplicates in a DataFrame happen at "row" level. Two rows with exactly the same values are considered to be duplicates

# %%
players = pd.DataFrame({
    'Name': [
        'Kobe Bryant',
        'LeBron James',
        'Kobe Bryant',
        'Carmelo Anthony',
        'Kobe Bryant',
    ],
    'Pos': [
        'SG',
        'SF',
        'SG',
        'SF',
        'SF'
    ]
})
players
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 2      Kobe Bryant  SG
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %%
players.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# Again, conceptually, "duplicated" means "all the column values should be duplicates". We can customize this with the subset parameter

# %%
players.duplicated(subset=['Name'])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
players.duplicated(subset=['Name'],keep='last')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# drop_duplicates() will take the same parameters

# %%
players.drop_duplicates()
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %%
players.drop_duplicates(subset=['Name'])
# Out:
#               Name Pos
# 0      Kobe Bryant  SG
# 1     LeBron James  SF
# 3  Carmelo Anthony  SF

# %%
players.drop_duplicates(subset=['Name'],keep='last')
# Out:
#               Name Pos
# 1     LeBron James  SF
# 3  Carmelo Anthony  SF
# 4      Kobe Bryant  SF

# %% [markdown]
# ## Text Handling
# Cleaning text values can be incredibly hard. Invalid text values involves, 99% of the time, mistyping, which is completely unpredictable and doesn't follow any pattern. Thankfully, it's not so common these days, where data-entry tasks have been replaced by machines. Still, let's explore the most common cases:

# %% [markdown]
# ### Splitting Columns

# %%
df = pd.DataFrame({
    'Data': [
        '1987_M_US _1',
        '1990?_M_UK_1',
        '1992_F_US_2',
        '1970?_M_   IT_1',
        '1985_F_I  T_2'
]})

# %%
df
# Out:
#               Data
# 0     1987_M_US _1
# 1     1990?_M_UK_1
# 2      1992_F_US_2
# 3  1970?_M_   IT_1
# 4    1985_F_I  T_2

# %% [markdown]
# The single columns rep the values as "year, sex, country, number of children". We can split it using the split method in pandas

# %%
df['Data'].str.split('_')
# Out:
# 0       [1987, M, US , 1]
# 1       [1990?, M, UK, 1]
# 2        [1992, F, US, 2]
# 3    [1970?, M,    IT, 1]
# 4      [1985, F, I  T, 2]
# Name: Data, dtype: object

# %%
df['Data'].str.split('_',expand=True)
# Out:
#        0  1      2  3
# 0   1987  M    US   1
# 1  1990?  M     UK  1
# 2   1992  F     US  2
# 3  1970?  M     IT  1
# 4   1985  F   I  T  2

# %%
df = df['Data'].str.split('_',expand=True)

# %%
df.columns = ['Year','Sex','Country','No. of Children']

# %%
df
# Out:
#     Year Sex Country No. of Children
# 0   1987   M     US                1
# 1  1990?   M      UK               1
# 2   1992   F      US               2
# 3  1970?   M      IT               1
# 4   1985   F    I  T               2

# %% [markdown]
# contains takes a regex/pattern as first value, so we need to escape the ? symbol as it has a special meaning for these patterns. Regular letters don't need escaping.

# %%
df['Year'].str.contains('\?')
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: Year, dtype: bool

# %%
df['Country'].str.contains('U')
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: Country, dtype: bool

# %% [markdown]
# Remove blank spaces using strip (lstrip or rstrip) or use replace

# %%
df['Country'].str.strip()
# Out:
# 0      US
# 1      UK
# 2      US
# 3      IT
# 4    I  T
# Name: Country, dtype: object

# %%
df['Country'].str.replace(' ','')
# Out:
# 0    US
# 1    UK
# 2    US
# 3    IT
# 4    IT
# Name: Country, dtype: object

# %%
df['Year'].str.replace(r'(?P<year>\d{4})\?', lambda m:m.group('year'))
# Out:
# <ipython-input-43-64670a831013>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Year'].str.replace(r'(?P<year>\d{4})\?', lambda m:m.group('year'))
# 0    1987
# 1    1990
# 2    1992
# 3    1970
# 4    1985
# Name: Year, dtype: object
